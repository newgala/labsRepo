# %% [markdown]
#  # Lets go to Portugal!

# %% [markdown]
# ## This notebook purpose is to show Angela's holidays preference.

# %% [markdown]
# ## Person's name

# %%
def greet(name):
    print("Hey, this is " + name)
greet('Angela')
# Out:
# Hey, this is Angela

# %% [markdown]
# ## Person's photo

# %% [markdown]
# ![about%20angela.jpg](attachment:about%20angela.jpg)

# %% [markdown]
# ## Holidays preference

# %%
x=input("Can you write 3 things you enjoy most during your holidays ? (ex.food, culture, nature etc...)")
print(x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4456/638823456.py in <module>
# ----> 1 x=input("Can you write 3 things you enjoy most during your holidays ? (ex.food, culture, nature etc...)")
#       2 print(x)
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# ## Holiday destination's photo

# %% [markdown]
# ![Landscape.jpg](attachment:Landscape.jpg)

# %% [markdown]
# ## Things to do in Porto
# - <font color='green'>Try Francesinha in a local place </font>
# - <font color='blue'> Take surfing lessons </font>
# - <font color='orange'> Attend some "El Fado" night </font>

# %% [markdown]
# ## Link to a youtube video to show the beauty of the destination!

# %% [markdown]
# https://www.youtube.com/watch?v=1cAK01jmTvo
